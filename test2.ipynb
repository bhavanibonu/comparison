# %%
import pandas as pd
data=pd.read_csv("C:/Users/bhava/OneDrive/Pictures/Desktop/GPTC/5th SEM/EXCEL/weight-height.csv")
data
# Out:
#       Gender     Height      Weight  values    Number
# 0       Male  73.847017  241.893563    35.0  1.000000
# 1       Male  68.781904  162.310473     NaN  2.000000
# 2       Male  74.110105  212.740856    57.0  3.000000
# 3       Male  71.730978  220.042470     NaN  4.000000
# 4       Male  69.881796  206.349801    59.0  5.000000
# ...      ...        ...         ...     ...       ...
# 9995  Female  66.172652  136.777454    43.0  6.555556
# 9996  Female  67.067155  170.867906    63.0  6.555556
# 9997  Female  63.867992  128.475319    47.0  6.555556
# 9998  Female  69.034243  163.852461    44.0  6.555556
# 9999  Female  61.944246  113.649103    50.0  6.555556
#
# [10000 rows x 5 columns]

# %%
import pandas as pd
data=pd.read_csv("C:/Users/bhava/OneDrive/Pictures/Desktop/GPTC/5th SEM/EXCEL/weight-height.csv")
data.isnull()
# Out:
#       Gender  Height  Weight  values  Number
# 0      False   False   False   False   False
# 1      False   False   False    True   False
# 2      False   False   False   False   False
# 3      False   False   False    True   False
# 4      False   False   False   False   False
# ...      ...     ...     ...     ...     ...
# 9995   False   False   False   False   False
# 9996   False   False   False   False   False
# 9997   False   False   False   False   False
# 9998   False   False   False   False   False
# 9999   False   False   False   False   False
#
# [10000 rows x 5 columns]

# %%
import seaborn as sns
sns.heatmap(data.isnull(),cbar=False)
# Out:
# <AxesSubplot:>

# %%
data_mean=data.mean()
data_fill=data.fillna(data_mean,inplace=True)
data_fill

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data=pd.read_csv("C:/Users/bhava/OneDrive/Pictures/Desktop/GPTC/5th SEM/EXCEL/weight-height.csv")
column=data[["Height", "Weight", "Number"]]
sns.pairplot(column)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_csv("C:/Users/bhava/OneDrive/Pictures/Desktop/GPTC/5th SEM/EXCEL/weight-height.csv")
plt.hist(data["values"],bins=100)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("C:/Users/bhava/OneDrive/Pictures/Desktop/GPTC/5th SEM/EXCEL/weight-height.csv")
column1 = df['Height']
column2 = df['Weight']
plt.figure(figsize=(8, 6))
sns.scatterplot(x=column1, y=column2)
plt.title('Bivariate Analysis')
plt.xlabel('Column 1')
plt.ylabel('Column 2')
plt.show()

# %%
import pandas as pd
data1=pd.read_csv("C:/Users/bhava/OneDrive/Pictures/Desktop/GPTC/5th SEM/EXCEL/weight-height.csv")
data2=pd.read_csv("C:/Users/bhava/OneDrive/Pictures/Desktop/GPTC/5th SEM/EXCEL/500_Person_Gender_Height_Weight_Index.csv")
data_merge=pd.merge(data1,data2,on="Gender")
data_merge
# Out:
#          Gender   Height_x    Weight_x  values    Number  Height_y  Weight_y  \
# 0          Male  73.847017  241.893563    35.0  1.000000       174        96
# 1          Male  73.847017  241.893563    35.0  1.000000       189        87
# 2          Male  73.847017  241.893563    35.0  1.000000       149        61
# 3          Male  73.847017  241.893563    35.0  1.000000       189       104
# 4          Male  73.847017  241.893563    35.0  1.000000       147        92
# ...         ...        ...         ...     ...       ...       ...       ...
# 2499995  Female  61.944246  113.649103    50.0  6.555556       198        50
# 2499996  Female  61.944246  113.649103    50.0  6.555556       170        53
# 2499997  Female  61.944246  113.649103    50.0  6.555556       150       153
# 2499998  Female  61.944246  113.649103    50.0  6.555556       184       121
# 2499999  Female  61.944246  113.649103    50.0  6.555556       141       136
#
#          Index
# 0            4
# ...

# %%
import pandas as pd
data1=pd.read_csv("C:/Users/bhava/OneDrive/Pictures/Desktop/GPTC/5th SEM/EXCEL/weight-height.csv")
data_dum=data1.drop_duplicates()
data_dum
# Out:
#       Gender     Height      Weight  values    Number
# 0       Male  73.847017  241.893563    35.0  1.000000
# 1       Male  68.781904  162.310473     NaN  2.000000
# 2       Male  74.110105  212.740856    57.0  3.000000
# 3       Male  71.730978  220.042470     NaN  4.000000
# 4       Male  69.881796  206.349801    59.0  5.000000
# ...      ...        ...         ...     ...       ...
# 9995  Female  66.172652  136.777454    43.0  6.555556
# 9996  Female  67.067155  170.867906    63.0  6.555556
# 9997  Female  63.867992  128.475319    47.0  6.555556
# 9998  Female  69.034243  163.852461    44.0  6.555556
# 9999  Female  61.944246  113.649103    50.0  6.555556
#
# [10000 rows x 5 columns]

# %%
import pandas as pd
data1=pd.read_csv("C:/Users/bhava/OneDrive/Pictures/Desktop/GPTC/5th SEM/EXCEL/weight-height.csv")
from scipy import stats
data1_column="Number"
data1["z-score"]=stats.zscore(data1["Number"])
data1["z-score"]
# Out:
# 0      -3.084305e+01
# 1      -2.529130e+01
# 2      -1.973955e+01
# 3      -1.418780e+01
# 4      -8.636054e+00
#             ...
# 9995    4.437849e-12
# 9996    4.437849e-12
# 9997    4.437849e-12
# 9998    4.437849e-12
# 9999    4.437849e-12
# Name: z-score, Length: 10000, dtype: float64

# %%
import pandas as pd
data1=pd.read_csv("C:/Users/bhava/OneDrive/Pictures/Desktop/GPTC/5th SEM/EXCEL/weight-height.csv")
Q1=data1["Height"].quantile(0.2)
Q3=data1["Weight"].quantile(0.20)
IQR=Q3-Q1
lower_bound=Q1 - 1.5 * IQR
upper_bound=Q3 + 1.5 * IQR
outlier=data1(data1["Height"] < lower_bound) | (data1["Weight"] > upper_bound)
outlier
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11304\364456626.py in <module>
#       6 lower_bound=Q1 - 1.5 * IQR
#       7 upper_bound=Q3 + 1.5 * IQR
# ----> 8 outlier=data1(data1["Height"] < lower_bound) | (data1["Weight"] > upper_bound)
#       9 outlier
#
# TypeError: 'DataFrame' object is not callable

# %%
import pandas as pd
data1=pd.read_csv("C:/Users/bhava/OneDrive/Pictures/Desktop/GPTC/5th SEM/EXCEL/weight-height.csv")
from sklearn.preprocessing import LabelEncoder
Label_encoder= LabelEncoder()
for column in ["Gender","Number"]:
    data1["Gender"]=Label_encoder.fit_transform(data1["Number"])
data1["Gender"]
# Out:
# 0       0
# 1       1
# 2       2
# 3       3
# 4       4
#        ..
# 9995    6
# 9996    6
# 9997    6
# 9998    6
# 9999    6
# Name: Gender, Length: 10000, dtype: int64

# %%
data1.info
# Out:
# <bound method DataFrame.info of       Gender     Height      Weight  values    Number
# 0          0  73.847017  241.893563    35.0  1.000000
# 1          1  68.781904  162.310473     NaN  2.000000
# 2          2  74.110105  212.740856    57.0  3.000000
# 3          3  71.730978  220.042470     NaN  4.000000
# 4          4  69.881796  206.349801    59.0  5.000000
# ...      ...        ...         ...     ...       ...
# 9995       6  66.172652  136.777454    43.0  6.555556
# 9996       6  67.067155  170.867906    63.0  6.555556
# 9997       6  63.867992  128.475319    47.0  6.555556
# 9998       6  69.034243  163.852461    44.0  6.555556
# 9999       6  61.944246  113.649103    50.0  6.555556
#
# [10000 rows x 5 columns]>
